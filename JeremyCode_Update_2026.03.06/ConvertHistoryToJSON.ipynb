# %%
# trying to create a quick plot for groupmate regarding loss
# didn't work because loading torch and matplotlib crashed my kernel
# have to dump history onto json so i can load data and create plot

# %%
import torch

# %%
history = torch.load("training_history_JeremyCode_RevisedSplit.pth", map_location = "cpu", weights_only = True)

# %%
with open("training_history.json", "w") as f:
    json.dump(history, f)
